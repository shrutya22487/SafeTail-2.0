# %%
from server1_regressor.predict_predictor import PredictPredictor
dp = PredictPredictor()

predicted_time = dp.predict_from_combination("pd")   # combination string example
print("Predicted detect processing time:", predicted_time)
# Out:
# Predicted detect processing time: 0.004021770000000001
# d:\Sem 7\BTP\SafeTail-2.0-1\.venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
